# %%
# %sql
-- Purpose: Generate comprehensive test data for f_invntry_bal_dly_hist table

CREATE OR REPLACE TABLE purgo_playground.f_invntry_bal_dly_hist (
    co_key STRING,
    g_account STRING,
    g_assignment_type STRING,
    g_capture_dt_yyyymmdd TIMESTAMP,
    g_company_cd STRING,
    g_company_currency_cd STRING,
    g_dnsa_dt_yyyymmdd TIMESTAMP,
    g_expiration_dt_yyyymmdd TIMESTAMP,
    g_item_nbr STRING,
    g_location_cd STRING,
    g_location_status_cd STRING,
    g_lot_effective_dt_yyyymmdd TIMESTAMP,
    g_lot_nbr STRING,
    g_lot_status_cd STRING,
    g_plant_cd STRING,
    g_qty_allocated DECIMAL(10,2),
    g_qty_available DECIMAL(10,2),
    g_qty_financial_nettable DECIMAL(10,2),
    g_qty_in_transit DECIMAL(10,2),
    g_qty_mrp_nettable DECIMAL(10,2),
    g_qty_on_hand DECIMAL(10,2),
    g_qty_shippable DECIMAL(10,2),
    g_source_system_cd STRING,
    g_unit_cost_company_currency DECIMAL(10,2),
    plant_key STRING,
    plant_location_key STRING,
    prod_key STRING,
    prod_plant_key STRING,
    prod_plant_location_key STRING,
    prod_plant_lot_key STRING,
    prod_plant_lot_location_key STRING
);

-- Happy Path: Valid complete record
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAP12345',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEM001',
    'LOC001',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOT001',
    'none',
    'CAGER',
    50.00,
    100.00,
    100.00,
    NULL,
    100.00,
    100.00,
    'nav_ger',
    20.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC001',
    'nav_gerITEM001',
    'nav_gerITEM001CAGER',
    'nav_gerITEM001CAGERLOC001',
    'nav_gerITEM001CAGERLOT001',
    'nav_gerITEM001CAGERLOT001LOC001'
);

-- Edge Case: Zero quantities
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAP00000',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEM_ZERO',
    'LOC_ZERO',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOT_ZERO',
    'none',
    'CAGER',
    0.00,
    0.00,
    0.00,
    NULL,
    0.00,
    0.00,
    'nav_ger',
    0.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_ZERO',
    'nav_gerITEM_ZERO',
    'nav_gerITEM_ZEROCAGER',
    'nav_gerITEM_ZEROCAGERLOC_ZERO',
    'nav_gerITEM_ZEROCAGERLOT_ZERO',
    'nav_gerITEM_ZEROCAGERLOT_ZEROLOC_ZERO'
);

-- Error Case: Negative quantities
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPNEG001',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEM_NEG',
    'LOC_NEG',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOT_NEG',
    'none',
    'CAGER',
    -10.00,
    -20.00,
    -30.00,
    NULL,
    -20.00,
    -10.00,
    'nav_ger',
    -5.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_NEG',
    'nav_gerITEM_NEG',
    'nav_gerITEM_NEGCAGER',
    'nav_gerITEM_NEGCAGERLOC_NEG',
    'nav_gerITEM_NEGCAGERLOT_NEG',
    'nav_gerITEM_NEGCAGERLOT_NEGLOC_NEG'
);

-- NULL Handling: Some nullable fields are NULL
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPNULL01',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    NULL,
    NULL,
    'ITEM_NULL',
    'LOC_NULL',
    'none',
    NULL,
    NULL,
    'none',
    'CAGER',
    25.50,
    75.00,
    75.00,
    NULL,
    75.00,
    75.00,
    'nav_ger',
    15.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_NULL',
    'nav_gerITEM_NULL',
    'nav_gerITEM_NULLCAGER',
    'nav_gerITEM_NULLCAGERLOC_NULL',
    'nav_gerITEM_NULLCAGERLOT_NULL',
    'nav_gerITEM_NULLCAGERLOT_NULLLOC_NULL'
);

-- Special Characters: Fields contain special characters
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAP!@#$$%',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEM@#$%',
    'LOC&*()',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOT*&^%',
    'none',
    'CAGER',
    30.00,
    150.00,
    150.00,
    NULL,
    150.00,
    150.00,
    'nav_ger',
    25.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_SPC',
    'nav_gerITEM_SPC',
    'nav_gerITEM_SPCCAGER',
    'nav_gerITEM_SPCCAGERLOC_SPC',
    'nav_gerITEM_SPCCAGERLOT_SPC',
    'nav_gerITEM_SPCCAGERLOT_SPCLOC_SPC'
);

-- Multi-byte Characters: Fields contain multi-byte characters
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAP测试',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEM测试',
    'LOC测试',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOT测试',
    'none',
    'CAGER',
    40.00,
    200.00,
    200.00,
    NULL,
    200.00,
    200.00,
    'nav_ger',
    30.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_MB',
    'nav_gerITEM_MB',
    'nav_gerITEM_MBCAGER',
    'nav_gerITEM_MBCAGERLOC_MB',
    'nav_gerITEM_MBCAGERLOT_MB',
    'nav_gerITEM_MBCAGERLOT_MBLOC_MB'
);

-- Missing Optional Fields: Apply default values
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPDEF01',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-25T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEM_DEF',
    'LOC_DEF',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'none',
    'none',
    'CAGER',
    60.00,
    300.00,
    300.00,
    NULL,
    300.00,
    300.00,
    'nav_ger',
    35.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_DEF',
    'nav_gerITEM_DEF',
    'nav_gerITEM_DEFCAGER',
    'nav_gerITEM_DEFCAGERLOC_DEF',
    'nav_gerITEM_DEFCAGERLOT_NONE',
    'nav_gerITEM_DEFCAGERLOT_NONELOC_DEF'
);

-- Boundary Condition: Maximum values
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPMAX01',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '9999-12-31T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEMMAX',
    'LOCMAX',
    'none',
    '9999-12-31T00:00:00.000+0000',
    'LOTMAX',
    'none',
    'CAGER',
    999999.99,
    999999.99,
    999999.99,
    NULL,
    999999.99,
    999999.99,
    'nav_ger',
    99999.99,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_MAX',
    'nav_gerITEM_MAX',
    'nav_gerITEM_MAXCAGER',
    'nav_gerITEM_MAXCAGERLOC_MAX',
    'nav_gerITEM_MAXCAGERLOT_MAX',
    'nav_gerITEM_MAXCAGERLOT_MAXLOC_MAX'
);

-- Boundary Condition: Minimum values
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPMIN01',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '0001-01-01T00:00:00.000+0000',
    '1900-01-01T00:00:00.000+0000',
    'ITEMMIN',
    'LOCMIN',
    'none',
    '0001-01-01T00:00:00.000+0000',
    'LOTMIN',
    'none',
    'CAGER',
    0.01,
    0.01,
    0.01,
    NULL,
    0.01,
    0.01,
    'nav_ger',
    0.01,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_MIN',
    'nav_gerITEM_MIN',
    'nav_gerITEM_MINCAGER',
    'nav_gerITEM_MINCAGERLOC_MIN',
    'nav_gerITEM_MINCAGERLOT_MIN',
    'nav_gerITEM_MINCAGERLOT_MINLOC_MIN'
);

-- Error Case: Invalid date formats
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPINVDATE',
    'Account',
    'invalid-timestamp',
    '1050',
    'EUR',
    'invalid-timestamp',
    'invalid-timestamp',
    'ITEMINVDATE',
    'LOCINVDATE',
    'none',
    'invalid-timestamp',
    'LOTINVDATE',
    'none',
    'CAGER',
    10.00,
    20.00,
    30.00,
    NULL,
    20.00,
    10.00,
    'nav_ger',
    15.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_INVDATE',
    'nav_gerITEM_INVDATE',
    'nav_gerITEM_INVDATECAGER',
    'nav_gerITEM_INVDATECAGERLOC_INVDATE',
    'nav_gerITEM_INVDATECAGERLOT_INVDATE',
    'nav_gerITEM_INVDATECAGERLOT_INVDATELOC_INVDATE'
);

-- Error Case: Missing mandatory fields
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    NULL,
    NULL,
    'Account',
    '2024-04-27T00:00:00.000+0000',
    NULL,
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    NULL,
    NULL,
    'none',
    '1900-01-01T00:00:00.000+0000',
    NULL,
    'none',
    'CAGER',
    20.00,
    40.00,
    40.00,
    NULL,
    40.00,
    40.00,
    'nav_ger',
    25.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_NULL',
    'nav_gerITEM_NULL',
    'nav_gerITEM_NULLCAGER',
    'nav_gerITEM_NULLCAGERLOC_NULL',
    'nav_gerITEM_NULLCAGERLOT_NONE',
    'nav_gerITEM_NULLCAGERLOT_NONELOC_NULL'
);

-- Special Case: Duplicate g_item_nbr within the same system
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPDUP01',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEMDUP',
    'LOCDUP',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOTDUP',
    'none',
    'CAGER',
    55.00,
    110.00,
    110.00,
    NULL,
    110.00,
    110.00,
    'nav_ger',
    22.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_DUP',
    'nav_gerITEM_DUP',
    'nav_gerITEM_DUPCAGER',
    'nav_gerITEM_DUPCAGERLOC_DUP',
    'nav_gerITEM_DUPCAGERLOT_DUP',
    'nav_gerITEM_DUPCAGERLOT_DUPLOC_DUP'
);

-- Boundary Condition: Extremely long strings
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAP' || repeat('LONGSTRING', 10),
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEM' || repeat('LONGSTRING', 10),
    'LOC' || repeat('LONGSTRING', 10),
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOT' || repeat('LONGSTRING', 10),
    'none',
    'CAGER',
    75.00,
    150.00,
    150.00,
    NULL,
    150.00,
    150.00,
    'nav_ger',
    35.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_LONG',
    'nav_gerITEM_LONG',
    'nav_gerITEM_LONGCAGER',
    'nav_gerITEM_LONGCAGERLOC_LONG',
    'nav_gerITEM_LONGCAGERLOT_LONG',
    'nav_gerITEM_LONGCAGERLOT_LONGLOC_LONG'
);

-- Conditional Population: Quantity allocated based on reservation
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPCOND01',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEMCOND',
    'LOCCOND',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOTCOND',
    'none',
    'CAGER',
    100.00,
    200.00,
    200.00,
    NULL,
    200.00,
    200.00,
    'nav_ger',
    40.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_COND',
    'nav_gerITEM_COND',
    'nav_gerITEM_CONDCAGER',
    'nav_gerITEM_CONDCAGERLOC_COND',
    'nav_gerITEM_CONDCAGERLOT_COND',
    'nav_gerITEM_CONDCAGERLOT_CONDLOC_COND'
);

-- Handle Missing Lot and Serial Numbers
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPMISSLOT',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEMMISS',
    'LOCMISS',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'none',
    'none',
    'CAGER',
    80.00,
    160.00,
    160.00,
    NULL,
    160.00,
    160.00,
    'nav_ger',
    32.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_MISS',
    'nav_gerITEM_MISS',
    'nav_gerITEM_MISSCAGER',
    'nav_gerITEM_MISSCAGERLOC_MISS',
    'nav_gerITEM_MISSCAGERLOT_NONE',
    'nav_gerITEM_MISSCAGERLOT_NONELOC_MISS'
);

-- Hardcoded Fields Verification
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPHARDCODE',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEMHARDC',
    'LOCHARDC',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOTHARDC',
    'none',
    'CAGER',
    90.00,
    180.00,
    180.00,
    NULL,
    180.00,
    180.00,
    'nav_ger',
    45.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_HARDC',
    'nav_gerITEM_HARDC',
    'nav_gerITEM_HARDCAGER',
    'nav_gerITEM_HARDCAGERLOC_HARDC',
    'nav_gerITEM_HARDCAGERLOT_HARDC',
    'nav_gerITEM_HARDCAGERLOT_HARDCLOC_HARDC'
);

-- Duplicate Record: Same g_item_nbr and g_location_cd
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPDUPLOC',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEMDUPLOC',
    'LOCDUPLOC',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOTDUPLOC',
    'none',
    'CAGER',
    70.00,
    140.00,
    140.00,
    NULL,
    140.00,
    140.00,
    'nav_ger',
    35.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_DUPLOC',
    'nav_gerITEM_DUPLOC',
    'nav_gerITEM_DUPLOCCAGER',
    'nav_gerITEM_DUPLOCCAGERLOC_DUPLOC',
    'nav_gerITEM_DUPLOCCAGERLOT_DUPLOC',
    'nav_gerITEM_DUPLOCCAGERLOT_DUPLOCLoc_DUPLOC'
);

-- Handle extremely large decimal values
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPEXTDEC',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEMEXTDEC',
    'LOCEXTDEC',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOTEXTDEC',
    'none',
    'CAGER',
    99999.99,
    99999.99,
    99999.99,
    NULL,
    99999.99,
    99999.99,
    'nav_ger',
    9999.99,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_EXTDEC',
    'nav_gerITEM_EXTDEC',
    'nav_gerITEM_EXTDECCAGER',
    'nav_gerITEM_EXTDECCAGERLOC_EXTDEC',
    'nav_gerITEM_EXTDECCAGERLOT_EXTDEC',
    'nav_gerITEM_EXTDECCAGERLOT_EXTDECLoc_EXTDEC'
);

-- Handle excessive timestamp precision
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPTIMESTAMP',
    'Account',
    '2024-04-27T23:59:59.999999+0000',
    '1050',
    'EUR',
    '2024-04-26T23:59:59.999999+0000',
    '9999-12-31T23:59:59.999999+0000',
    'ITEMTIMESTAMP',
    'LOCTIMESTAMP',
    'none',
    '1900-01-01T23:59:59.999999+0000',
    'LOTTIMESTAMP',
    'none',
    'CAGER',
    85.00,
    170.00,
    170.00,
    NULL,
    170.00,
    170.00,
    'nav_ger',
    42.50,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_TIMESTMP',
    'nav_gerITEM_TIMESTMP',
    'nav_gerITEM_TIMESTMPCAGER',
    'nav_gerITEM_TIMESTMPCAGERLOC_TIMESTMP',
    'nav_gerITEM_TIMESTMPCAGERLOT_TIMESTMP',
    'nav_gerITEM_TIMESTMPCAGERLOT_TIMESTMPLoc_TIMESTMP'
);

-- Handle map and struct data types (if applicable)
-- Assuming some fields are MAP or STRUCT, but based on given fields all are basic types
-- Adding records with nested structures as STRING representations

INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPMAP01',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEMMAP',
    'LOCMAP',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOTMAP',
    'none',
    'CAGER',
    95.00,
    190.00,
    190.00,
    NULL,
    190.00,
    190.00,
    'nav_ger',
    47.50,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_MAP',
    'nav_gerITEM_MAP',
    'nav_gerITEM_MAPCAGER',
    'nav_gerITEM_MAPCAGERLOC_MAP',
    'nav_gerITEM_MAPCAGERLOT_MAP',
    'nav_gerITEM_MAPCAGERLOT_MAPLOC_MAP'
);

-- Additional Happy Path Records
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPHAPPY02',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    '2024-04-26T00:00:00.000+0000',
    '9999-12-31T00:00:00.000+0000',
    'ITEMHAPPY02',
    'LOCHAPPY02',
    'none',
    '1900-01-01T00:00:00.000+0000',
    'LOTHAPPY02',
    'none',
    'CAGER',
    120.00,
    240.00,
    240.00,
    NULL,
    240.00,
    240.00,
    'nav_ger',
    60.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_HAPPY02',
    'nav_gerITEM_HAPPY02',
    'nav_gerITEM_HAPPY02CAGER',
    'nav_gerITEM_HAPPY02CAGERLOC_HAPPY02',
    'nav_gerITEM_HAPPY02CAGERLOT_HAPPY02',
    'nav_gerITEM_HAPPY02CAGERLOT_HAPPY02LOC_HAPPY02'
);

-- Additional Error Cases
INSERT INTO purgo_playground.f_invntry_bal_dly_hist VALUES (
    'nav_ger1050',
    'SAPERR01',
    'Account',
    '2024-04-27T00:00:00.000+0000',
    '1050',
    'EUR',
    'invalid-date',
    'invalid-date',
    'ITEMERR01',
    'LOCERR01',
    'none',
    'invalid-date',
    'LOTERR01',
    'none',
    'CAGER',
    110.00,
    220.00,
    220.00,
    NULL,
    220.00,
    220.00,
    'nav_ger',
    55.00,
    'nav_gerCAGER',
    'nav_gerCAGERLOC_ERR01',
    'nav_gerITEM_ERR01',
    'nav_gerITEM_ERR01CAGER',
    'nav_gerITEM_ERR01CAGERLOC_ERR01',
    'nav_gerITEM_ERR01CAGERLOT_ERR01',
    'nav_gerITEM_ERR01CAGERLOT_ERR01LOC_ERR01'
);
